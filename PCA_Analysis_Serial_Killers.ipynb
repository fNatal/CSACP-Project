# %% [markdown]
# # PCA Analysis on Updated Serial Killer Dataset
# This notebook performs Principal Component Analysis (PCA) to reduce dimensionality and visualize trends in the updated dataset.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv('Updated_Imputed_Dataset.csv')

# %%
# Select numeric columns
numeric_columns = data.select_dtypes(include=[np.number]).columns.tolist()

# %%
# Preprocessing pipeline: impute missing values and scale features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ]), numeric_columns)
    ])

# %%
# Set up the PCA pipeline
pca = PCA(n_components=2)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('pca', pca)
])

# %%
# Apply PCA
pca_result = pipeline.fit_transform(data)
pca_df = pd.DataFrame(pca_result, columns=['PC1', 'PC2'])

# %%
# Plot PCA result
plt.figure(figsize=(8,6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], alpha=0.5)
plt.title('PCA of Serial Killer Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()
